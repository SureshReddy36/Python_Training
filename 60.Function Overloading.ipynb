# %% [markdown]
# //Function overloading is not supported by the python

# %%
class FunctionOverloading:
    def add(self,a):
        return a
    def add(self,a,b):
        return a+b
    def add(self,a,b,c):
        return a+b+c
obj=FunctionOverloading()
obj.add(10)
obj.add(10,20)
obj.add(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       7         return a+b+c
#       8 obj=FunctionOverloading()
# ----> 9 obj.add(10)
#      10 obj.add(10,20)
#      11 obj.add(10,20,30)
#
# TypeError: FunctionOverloading.add() missing 2 required positional arguments: 'b' and 'c'

# %%
class FunctionOverloading:
    def add(self,a):
        return a
    def add(self,a,b):
        return a+b
    def add(self,a,b,c):
        return a+b+c
obj=FunctionOverloading()
#obj.add(10)
obj.add(10,20)
obj.add(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8 obj=FunctionOverloading()
#       9 #obj.add(10)
# ---> 10 obj.add(10,20)
#      11 obj.add(10,20,30)
#
# TypeError: FunctionOverloading.add() missing 1 required positional argument: 'c'

# %%
class FunctionOverloading:
    def add(self,a):
        return a
    def add(self,a,b):
        return a+b
    def add(self,a,b,c):
        return a+b+c
obj=FunctionOverloading()
#obj.add(10)
#obj.add(10,20)
obj.add(10,20,30)
# Out:
# 60
