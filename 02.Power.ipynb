# %% [markdown]
# //Write a program to accept two inputs from the user in the float format and then convert it into integer data type amd calculate the a power b

# %%
a=float(input("enter the first number:"))
b=float(input("enter the second number"))
a=int(a)
b=int(b)
print(a**b)
# Out:
# enter the first number:2.4
# enter the second number3.5
# 8
